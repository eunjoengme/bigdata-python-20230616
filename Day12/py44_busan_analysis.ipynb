# %% [markdown]
# #### 데이터 전처리 및 시각화
#
# ##### 전처리
# 데이터프레임 병합

# %%
# import
import pandas as pd
import numpy as np

import folium
import json

# %%
# 스타벅스 매장리스트
sbuck_df = pd.read_excel('./busan_starbucks.xlsx', header=0)
sbuck_df.tail()
# Out:
#             매장명         위도          경도     매장타입                          주소
# 132  해운대 엑스더스카이  35.159965  129.169756  general          부산광역시 해운대구 달맞이길30
# 133     센텀신세계3F  35.169063  129.129066  general    부산광역시 해운대구 센텀남대로 35 (우동)
# 134      해운대중동역  35.167185  129.167886  general     부산광역시 해운대구 좌동순환로 6 (중동)
# 135       센텀몰1F  35.169810  129.127783  general     부산광역시 해운대구 센텀4로 15 (우동)
# 136    그랜드조선 부산  35.160034  129.163051  general  부산광역시 해운대구 해운대해변로 292 (중동)

# %%
sbuck_df['주소'][136].split()[1]
# Out:
# '해운대구'

# %%
gu_list = []
for item in sbuck_df['주소']:
    gu = item.split()[1]
    gu_list.append(gu)

sbuck_df['구'] = gu_list
sbuck_df.tail()
# Out:
#             매장명         위도          경도     매장타입                          주소  \
# 132  해운대 엑스더스카이  35.159965  129.169756  general          부산광역시 해운대구 달맞이길30
# 133     센텀신세계3F  35.169063  129.129066  general    부산광역시 해운대구 센텀남대로 35 (우동)
# 134      해운대중동역  35.167185  129.167886  general     부산광역시 해운대구 좌동순환로 6 (중동)
# 135       센텀몰1F  35.169810  129.127783  general     부산광역시 해운대구 센텀4로 15 (우동)
# 136    그랜드조선 부산  35.160034  129.163051  general  부산광역시 해운대구 해운대해변로 292 (중동)
#
#         구
# 132  해운대구
# 133  해운대구
# 134  해운대구
# 135  해운대구
# 136  해운대구

# %% [markdown]
# ##### 부산시 행정구역별 위경도 전처리

# %%
busan_loc_df = pd.read_excel('./대한민국_행정구역_위경도.xlsx')
busan_loc_df.head()
# Out:
#    docity  do city   longitude   latitude
# 0     NaN  강원  강릉시  128.878497  37.749136
# 1     NaN  강원  고성군  128.470164  38.377961
# 2     NaN  강원  동해시  129.116633  37.521931
# 3     NaN  강원  삼척시  129.167489  37.447086
# 4     NaN  강원  속초시  128.594167  38.204275

# %%
busan_gu_df = busan_loc_df[busan_loc_df['do'] == '부산시']
busan_gu_df.head()
# Out:
#      docity   do city   longitude   latitude
# 122     NaN  부산시  강서구  128.982908  35.209164
# 123     NaN  부산시  금정구  129.094319  35.240078
# 124     NaN  부산시   남구  129.086500  35.133408
# 125     NaN  부산시   동구  129.059175  35.135894
# 126     NaN  부산시  동래구  129.085856  35.201872

# %%
busan_gu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 122 to 137
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     0 non-null      float64
#  1   do         16 non-null     object
#  2   city       16 non-null     object
#  3   longitude  16 non-null     float64
#  4   latitude   16 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 768.0+ bytes

# %%
busan_gu_df.to_excel('./busan_gu_info.xlsx', index=False)

# %% [markdown]
# ##### 부산광역시 구별 스타벅스 매장수 구하기

# %%
sbuck_gu_counts= sbuck_df.pivot_table(index='구',
                                      values='매장명',
                                      aggfunc='count').rename(columns= {'매장명': '스타벅스_매장수'})
sbuck_gu_counts.head()
# Out:
#      스타벅스_매장수
# 구
# 강서구         5
# 금정구         8
# 기장군         6
# 남구          6
# 동구          4

# %%
# busan_gu_df 수정
busan_gu_df = busan_gu_df[['do', 'city', 'latitude', 'longitude']]
columns = {'do':'도', 'city':'구', 'latitude':'위도', 'longitude':'경도'}
busan_gu_df.rename(columns=columns, inplace=True)
busan_gu_df.reset_index(drop=True, inplace=True)

# %%
busan_gu_df.head()
# Out:
#      도    구         위도          경도
# 0  부산시  강서구  35.209164  128.982908
# 1  부산시  금정구  35.240078  129.094319
# 2  부산시   남구  35.133408  129.086500
# 3  부산시   동구  35.135894  129.059175
# 4  부산시  동래구  35.201872  129.085856

# %%
busan_sgg = pd.merge(busan_gu_df, sbuck_gu_counts, how='left', on='구')
busan_sgg
# Out:
#       도     구         위도          경도  스타벅스_매장수
# 0   부산시   강서구  35.209164  128.982908         5
# 1   부산시   금정구  35.240078  129.094319         8
# 2   부산시    남구  35.133408  129.086500         6
# 3   부산시    동구  35.135894  129.059175         4
# 4   부산시   동래구  35.201872  129.085856         9
# 5   부산시  부산진구  35.159953  129.055319        19
# 6   부산시    북구  35.194181  128.992475         5
# 7   부산시   사상구  35.149467  128.993333         7
# 8   부산시   사하구  35.101428  128.977042         7
# 9   부산시    서구  35.094836  129.026378         4
# 10  부산시   수영구  35.142467  129.115375         8
# 11  부산시   연제구  35.173186  129.082075         9
# 12  부산시   영도구  35.088117  129.070186         2
# 13  부산시    중구  35.103217  129.034508         6
# 14  부산시  해운대구  35.160019  129.165808        32
# 15  부산시   기장군  35.244775  129.222287         6

# %%
busan_pop = pd.read_excel('./부산광역시_인구_2307.xlsx', usecols='A,S:T', header=2)
busan_pop.head()
columns = {'부산광역시':'구', 1561008: '세대수', 3364066: '인구수'}
busan_pop.rename(columns=columns, inplace=True)
busan_pop
# Out:
#        구     세대수     인구수
# 0     중구   24099   41862
# 1     서구   53670  107035
# 2     동구   46196   88013
# 3    영도구   54335  109774
# 4   부산진구  179744  360354
# 5    동래구  119963  274419
# 6     남구  118462  262385
# 7     북구  123573  279814
# 8   해운대구  170251  389843
# 9    사하구  141398  306547
# 10   금정구  106954  224488
# 11   강서구   62376  148176
# 12   연제구   93650  204094
# 13   수영구   87985  177230
# 14   사상구   99173  208557
# 15   기장군   79179  181475

# %%
busan_sgg = pd.merge(busan_sgg, busan_pop, how='left', on='구')
busan_sgg.head()
# Out:
#      도    구         위도          경도  스타벅스_매장수   세대수_x   인구수_x   세대수_y   인구수_y
# 0  부산시  강서구  35.209164  128.982908         5   62376  148176   62376  148176
# 1  부산시  금정구  35.240078  129.094319         8  106954  224488  106954  224488
# 2  부산시   남구  35.133408  129.086500         6  118462  262385  118462  262385
# 3  부산시   동구  35.135894  129.059175         4   46196   88013   46196   88013
# 4  부산시  동래구  35.201872  129.085856         9  119963  274419  119963  274419

# %%
# 사업체수
busan_biz = pd.read_excel('./부산_사업체수_202307.xlsx', usecols='A:C', header=3)
columns = {'합계':'구', 401254:'사업체수', 1544504:'종사자수'}
busan_biz.rename(columns=columns, inplace=True)
busan_biz.head()
# Out:
#       구   사업체수    종사자수
# 0    중구  18306   69033
# 1    서구  11376   45728
# 2    동구  18208   76827
# 3   영도구  11616   46978
# 4  부산진구  44355  174317

# %%
busan_sgg_stat = pd.merge(busan_sgg, busan_biz, how='left', on='구')
busan_sgg_stat.tail()
# Out:
#       도     구         위도          경도  스타벅스_매장수   세대수_x   인구수_x   세대수_y  \
# 11  부산시   연제구  35.173186  129.082075         9   93650  204094   93650
# 12  부산시   영도구  35.088117  129.070186         2   54335  109774   54335
# 13  부산시    중구  35.103217  129.034508         6   24099   41862   24099
# 14  부산시  해운대구  35.160019  129.165808        32  170251  389843  170251
# 15  부산시   기장군  35.244775  129.222287         6   79179  181475   79179
#
#      인구수_y   사업체수    종사자수
# 11  204094  23946   96109
# 12  109774  11616   46978
# 13   41862  18306   69033
# 14  389843  40946  154115
# 15  181475  17930   77117

# %%
busan_sgg_stat.to_excel('./busan_sgg_stat.xlsx', index=False)

# %% [markdown]
# ##### 데이터 시각화

# %%
sbuck_df.tail()
# Out:
#             매장명         위도          경도     매장타입                          주소  \
# 132  해운대 엑스더스카이  35.159965  129.169756  general          부산광역시 해운대구 달맞이길30
# 133     센텀신세계3F  35.169063  129.129066  general    부산광역시 해운대구 센텀남대로 35 (우동)
# 134      해운대중동역  35.167185  129.167886  general     부산광역시 해운대구 좌동순환로 6 (중동)
# 135       센텀몰1F  35.169810  129.127783  general     부산광역시 해운대구 센텀4로 15 (우동)
# 136    그랜드조선 부산  35.160034  129.163051  general  부산광역시 해운대구 해운대해변로 292 (중동)
#
#         구
# 132  해운대구
# 133  해운대구
# 134  해운대구
# 135  해운대구
# 136  해운대구

# %%
sbuck_map = folium.Map(location=[35.189294, 129.061272], tiles='Stamen Terrain', zoom_start=11)

for idx in sbuck_df.index:
    lat = sbuck_df.loc[idx, '위도']
    lng = sbuck_df.loc[idx, '경도']
    name = sbuck_df.loc[idx, '매장명']

    folium.CircleMarker(location=[lat, lng], fill=True, fill_color='green', fill_opacity=1, popup=name,
                        color='yellow', weight=1, radius=3).add_to(sbuck_map)

sbuck_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e1552b3b64fdd909faae0626b05cdaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e1552b3b64fdd909faae0626b05cdaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e1552b3b64fdd909faae0626b05cdaa = L.map(
#                 &quot;map_3e1552b3b64fdd909faae0626b05cdaa&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6700724f74e190fa45716fbd312f5953 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e1552b3b64fdd909faae0626b05cdaa);
#
#
#             var circle_marker_2eb73957543c3a72c9b42a8a9c9f0fae = L.circleMarker(
#                 [35.262466, 129.091353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3e1552b3b64fdd909faae0626b05cdaa);
#
#
#         var popup_3a9d1e4c8855ef05c8cc6a5b1772d3ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_139675df58e62a34504d8232e4145966 = $(`&lt;div id=&quot;html_139675df58e62a34504d8232e4145966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;금정남산동DT&lt;/div&gt;`)[0];
#                 popup_3a9d1e4c8855ef05c8cc6a5b1772d3ad.setContent(html_139675df58e62a34504d8232e4145966);
#
#
#
#         circle_marker_2eb73957543c3a72c9b42a8a9c9f0fae.bindPopup(popup_3a9d1e4c8855ef05c8cc6a5b1772d3ad)
#         ;
#
#
#
#
#             var circle_marker_52d136d17235d7f097e14d38e2a02e9e = L.circleMarker(
#                 [35.238784, 129.092964],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3e1552b3b64fdd909faae0626b05cdaa);
#
#
#         var popup_e97688ec7c14077ac292523a6be9b96e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f959dd5ba50320a045c27c2845658495 = $(`&lt;div id=&quot;html_f959dd5ba50320a045c27c2845658495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;금정구청DT&lt;/div&gt;`)[0];
#                 popup_e97688ec7c14077ac292523a6be9b96e.setContent(html_f959dd5ba50320a045c27c2845658495);
#
#
#
#         circle_marker_52d136d17235d7f097e14d38e2a02e9e.bindPopup(popup_e97688ec7c14077ac292523a6be9b96e)
#         ;
#
#
#
#
#             var circle_marker_c8024a9d775f6ae5e0a322999f375792 = L.circleMarker(
#                 [35.224006, 129.08656],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3e1552b3b64fdd909faae0626b05cdaa);
#
#
#         var popup_efe0fb661eeabe965bdf7de15e9abce8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1fe84dd165f934b146358b5f79ab149 = $(`&lt;div id=&quot;html_d1fe84dd165f934b146358b5f79ab149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;온천장역DT&lt;/div&gt;`)[0];
#                 popup_efe0fb661eeabe965bdf7de15e9abce8.setContent(html_d1fe84dd165f934b146358b5f79ab149);
#
#
#
#         circle_marker_c8024a9d775f6ae5e0a322999f375792.bindPopup(popup_efe0fb661eeabe965bdf7de15e9abce8)
#         ;
#
#
#
#
#             var circle_marker_cd

# %%
sbuck_map2 = folium.Map(location=[35.189294, 129.061272], tiles='Stamen Terrain', zoom_start=11)

for idx in sbuck_df.index:
    lat = sbuck_df.loc[idx, '위도']
    lng = sbuck_df.loc[idx, '경도']
    name = sbuck_df.loc[idx, '매장명']
    type = sbuck_df.loc[idx, '매장타입']

    # 매장타입별 색상
    fillcolor = ''
    size = 2
    if type == 'general':
        fillcolor = 'gray'
        size = 2
    elif type == 'reserve':
        fillcolor = 'black'
        size = 5
    elif type == 'generalDT':
        fillcolor = 'red'
        size = 3
    elif type == 'generalWT':
        fillcolor = 'blue'
        size = 3

    folium.CircleMarker(location=[lat, lng], fill=True, fill_color=fillcolor, fill_opacity=1, popup=name,
                        color='yellow', weight=1, radius=size).add_to(sbuck_map2)

sbuck_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ce82fdd516a7f1c204d1aaba974d136 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ce82fdd516a7f1c204d1aaba974d136&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ce82fdd516a7f1c204d1aaba974d136 = L.map(
#                 &quot;map_2ce82fdd516a7f1c204d1aaba974d136&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef878f105d8fc6873bca3d2db310223f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ce82fdd516a7f1c204d1aaba974d136);
#
#
#             var circle_marker_9fea5b1cb6e4a030c7fa14b6aea9cd15 = L.circleMarker(
#                 [35.262466, 129.091353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_2ce82fdd516a7f1c204d1aaba974d136);
#
#
#         var popup_1a7b8eaf0961f44ab17e0a00c49c8085 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_539a56ac9f973b8d7aaa476b6b4bc2fe = $(`&lt;div id=&quot;html_539a56ac9f973b8d7aaa476b6b4bc2fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;금정남산동DT&lt;/div&gt;`)[0];
#                 popup_1a7b8eaf0961f44ab17e0a00c49c8085.setContent(html_539a56ac9f973b8d7aaa476b6b4bc2fe);
#
#
#
#         circle_marker_9fea5b1cb6e4a030c7fa14b6aea9cd15.bindPopup(popup_1a7b8eaf0961f44ab17e0a00c49c8085)
#         ;
#
#
#
#
#             var circle_marker_358a71e13a866bc904736a18391c3efc = L.circleMarker(
#                 [35.238784, 129.092964],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_2ce82fdd516a7f1c204d1aaba974d136);
#
#
#         var popup_eb7582ef522db5f02bce1970327411e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_805b0b7d6c5345737576bc068be4314d = $(`&lt;div id=&quot;html_805b0b7d6c5345737576bc068be4314d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;금정구청DT&lt;/div&gt;`)[0];
#                 popup_eb7582ef522db5f02bce1970327411e6.setContent(html_805b0b7d6c5345737576bc068be4314d);
#
#
#
#         circle_marker_358a71e13a866bc904736a18391c3efc.bindPopup(popup_eb7582ef522db5f02bce1970327411e6)
#         ;
#
#
#
#
#             var circle_marker_106aa6d6d8005e2232545190c6bd8f6d = L.circleMarker(
#                 [35.224006, 129.08656],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_2ce82fdd516a7f1c204d1aaba974d136);
#
#
#         var popup_131bdbdbe42a11652b318faf020e2cc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d88993a0e369e69a4cacb143286551ea = $(`&lt;div id=&quot;html_d88993a0e369e69a4cacb143286551ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;온천장역DT&lt;/div&gt;`)[0];
#                 popup_131bdbdbe42a11652b318faf020e2cc1.setContent(html_d88993a0e369e69a4cacb143286551ea);
#
#
#
#         circle_marker_106aa6d6d8005e2232545190c6bd8f6d.bindPopup(popup_131bdbdbe42a11652b318faf020e2cc1)
#         ;
#
#
#
#
#             var circle_marker_5baa85f8

# %%
# 시군구경계표시
sgg_geojson_path = './TL_SCCO_SIG.json'
busan_sgg_geo = json.load(open(sgg_geojson_path, encoding='utf-8'))

sbuck_map3 = folium.Map(location=[35.189294, 129.061272], tiles='CartoDB dark_matter', zoom_start=11)

folium.GeoJson(busan_sgg_geo, name='부산행정구역').add_to(sbuck_map3)

sbuck_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_969b845f35ff7d1515def7e840ef9624 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_969b845f35ff7d1515def7e840ef9624&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_969b845f35ff7d1515def7e840ef9624 = L.map(
#                 &quot;map_969b845f35ff7d1515def7e840ef9624&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b36b5d311707b56d30402f6906d940a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_969b845f35ff7d1515def7e840ef9624);
#
#
#
#         function geo_json_8904dcc966cd4cb222cd45906f430a45_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8904dcc966cd4cb222cd45906f430a45 = L.geoJson(null, {
#                 onEachFeature: geo_json_8904dcc966cd4cb222cd45906f430a45_onEachFeature,
#
#         });
#
#         function geo_json_8904dcc966cd4cb222cd45906f430a45_add (data) {
#             geo_json_8904dcc966cd4cb222cd45906f430a45
#                 .addData(data)
#                 .addTo(map_969b845f35ff7d1515def7e840ef9624);
#         }
#             geo_json_8904dcc966cd4cb222cd45906f430a45_add({&quot;bbox&quot;: [124.7893154389517, 33.17261058239259, 130.96325546758288, 38.54261253850525], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0411960872414, 35.10866377584849], [129.0263891249103, 35.09567543786908], [129.027468686406, 35.1155083560405], [129.0411960872414, 35.10866377584849]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.00445134557444, 35.078439676204596], [128.9997518119125, 35.123258941810164], [129.0121583473841, 35.13745819983691], [129.02562945082866, 35.13569484293786], [129.027468686406, 35.1155083560405], [129.0263891249103, 35.09567543786908], [129.00445134557444, 35.078439676204596]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26140&quot;, &quot;SIG_ENG_NM&quot;: &quot;Seo-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc11c\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.06453158641534, 35.141413884274215], [129.06545956779965, 35.13562671889399], [129.0411960872414, 35.10866377584849], [129.027468686406, 35.1155083560405], [129.02562945082866, 35.13569484293786], [129.06453158641534, 35.141413884274215]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26170&quot;, &quot;SIG_ENG_NM&quot;: &quot;Dong-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ub3d9\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0441284826078, 35.19946126955921], [129.04825560885078, 35.194547289853595], [129.0619699617844, 35.17929917076201], [129.06260505610896, 35.17735200319737], [129.06277510936656, 35.17729882756537], [129.0636150421614, 35.17720648095883], [129.06517650238175, 35.1770457771076], [129.06517559053268, 35.17703084217908], [129.06718207036297, 35.17638249974108], [129.06723395355255, 35.17657545112467], [129.0674237899668, 35.17652924369737], [129.0780938050298, 35.164372666167935], [129.07854283428412, 35.16316459360052], [129.08283185447527, 35.158173763598015], [129.06479001335273, 35.149327709816454], [129.0632642145734, 35.148796661739155], [129.06453158641534, 35.141413884274215], [129.02562945082866, 35.13569484293786], [129.0121583473841, 35.13745819983691], [129.01926481305176, 35.18046670766861], [129.0198882418209, 35.180696251773874], [129.02108500943768, 35.18747513680664], [129.0441284826078, 35.19946126955921]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26230&quot;, &quot;SIG_ENG_NM&quot;: &quot;Busanjin-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ubd80\uc0b0\uc9c4\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.11024005400392, 35.2101373741231], [129.11545694382227, 35.18650038207183], [129.1151769887035, 35.18354275935317], [129.04825560885078, 35.194547289853595], [129.0441284826078, 35.19946126955921], [129.06176727159612, 35.225841741259146], [129.11024005400392, 35.2101373741231]]], &quot;type&quot;: &qu

# %%
sbuck_mean = busan_sgg_stat['스타벅스_매장수'].mean()
sbuck_mean
# Out:
# 8.5625

# %%
# 시군구경계표시
sgg_geojson_path = './TL_SCCO_SIG.json'
busan_sgg_geo = json.load(open(sgg_geojson_path, encoding='utf-8'))

sbuck_map3 = folium.Map(location=[35.189294, 129.061272], tiles='CartoDB dark_matter', zoom_start=11)

folium.GeoJson(busan_sgg_geo, name='부산행정구역').add_to(sbuck_map3)

for idx in busan_sgg_stat.index:
    lat = busan_sgg_stat.loc[idx, '위도']
    lng = busan_sgg_stat.loc[idx, '경도']
    count = busan_sgg_stat.loc[idx, '스타벅스_매장수']

    if count > sbuck_mean: # 구별 평균치보다 매장수가 많음
        fillcolor = 'red'
    else:
        fillcolor = 'blue'

    folium.CircleMarker(location=[lat, lng], color='#ffff00', fill_color=fillcolor, fill_opacity=0.7, weight=1.5, radius=count/2, popup=count).add_to(sbuck_map3)

sbuck_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d74ef6de57633c6e20703f5b655248b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d74ef6de57633c6e20703f5b655248b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d74ef6de57633c6e20703f5b655248b = L.map(
#                 &quot;map_6d74ef6de57633c6e20703f5b655248b&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79042ea83402280cc4720a73f9cd929b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6d74ef6de57633c6e20703f5b655248b);
#
#
#
#         function geo_json_aa48c5cc665f454c550cb5ef95463e17_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_aa48c5cc665f454c550cb5ef95463e17 = L.geoJson(null, {
#                 onEachFeature: geo_json_aa48c5cc665f454c550cb5ef95463e17_onEachFeature,
#
#         });
#
#         function geo_json_aa48c5cc665f454c550cb5ef95463e17_add (data) {
#             geo_json_aa48c5cc665f454c550cb5ef95463e17
#                 .addData(data)
#                 .addTo(map_6d74ef6de57633c6e20703f5b655248b);
#         }
#             geo_json_aa48c5cc665f454c550cb5ef95463e17_add({&quot;bbox&quot;: [124.7893154389517, 33.17261058239259, 130.96325546758288, 38.54261253850525], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0411960872414, 35.10866377584849], [129.0263891249103, 35.09567543786908], [129.027468686406, 35.1155083560405], [129.0411960872414, 35.10866377584849]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.00445134557444, 35.078439676204596], [128.9997518119125, 35.123258941810164], [129.0121583473841, 35.13745819983691], [129.02562945082866, 35.13569484293786], [129.027468686406, 35.1155083560405], [129.0263891249103, 35.09567543786908], [129.00445134557444, 35.078439676204596]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26140&quot;, &quot;SIG_ENG_NM&quot;: &quot;Seo-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc11c\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.06453158641534, 35.141413884274215], [129.06545956779965, 35.13562671889399], [129.0411960872414, 35.10866377584849], [129.027468686406, 35.1155083560405], [129.02562945082866, 35.13569484293786], [129.06453158641534, 35.141413884274215]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26170&quot;, &quot;SIG_ENG_NM&quot;: &quot;Dong-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ub3d9\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0441284826078, 35.19946126955921], [129.04825560885078, 35.194547289853595], [129.0619699617844, 35.17929917076201], [129.06260505610896, 35.17735200319737], [129.06277510936656, 35.17729882756537], [129.0636150421614, 35.17720648095883], [129.06517650238175, 35.1770457771076], [129.06517559053268, 35.17703084217908], [129.06718207036297, 35.17638249974108], [129.06723395355255, 35.17657545112467], [129.0674237899668, 35.17652924369737], [129.0780938050298, 35.164372666167935], [129.07854283428412, 35.16316459360052], [129.08283185447527, 35.158173763598015], [129.06479001335273, 35.149327709816454], [129.0632642145734, 35.148796661739155], [129.06453158641534, 35.141413884274215], [129.02562945082866, 35.13569484293786], [129.0121583473841, 35.13745819983691], [129.01926481305176, 35.18046670766861], [129.0198882418209, 35.180696251773874], [129.02108500943768, 35.18747513680664], [129.0441284826078, 35.19946126955921]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26230&quot;, &quot;SIG_ENG_NM&quot;: &quot;Busanjin-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ubd80\uc0b0\uc9c4\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.11024005400392, 35.2101373741231], [129.11545694382227, 35.18650038207183], [129.1151769887035, 35.18354275935317], [129.04825560885078, 35.194547289853595], [129.0441284826078, 35.19946126955921], [129.06176727159612, 35.225841741259146], [129.11024005400392, 35.2101373741231]]], &quot;type&quot;: &qu

# %%
# 시군구경계표시
sgg_geojson_path = './TL_SCCO_SIG.json'
busan_sgg_geo = json.load(open(sgg_geojson_path, encoding='utf-8'))

sbuck_map4 = folium.Map(location=[35.189294, 129.061272], tiles='CartoDB dark_matter', zoom_start=10)

folium.GeoJson(busan_sgg_geo, name='부산행정구역').add_to(sbuck_map4)

folium.Choropleth(
    geo_data=busan_sgg_geo,
    data=busan_sgg_stat,
    columns=['구', '스타벅스_매장수'],
    fill_color='Purples', # YlGn, RdYlGn, Spectral, Accent, Reds, Greens, Blues, Oranges, Purples, Greys, PuOr, OrRd
    fill_opacity=0.7, 
    line_opacity=0.5,
    key_on='properties.SIG_KOR_NM', # 이게 핵심 - key값이 없으면 지도에 색상표시 못함
).add_to(sbuck_map4)

sbuck_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed475621105aef5e10f283f630046453 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed475621105aef5e10f283f630046453&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed475621105aef5e10f283f630046453 = L.map(
#                 &quot;map_ed475621105aef5e10f283f630046453&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b0a4576b72e26281459112aa4b996da = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed475621105aef5e10f283f630046453);
#
#
#
#         function geo_json_a646078a72f07ae938f80a87b18921d9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a646078a72f07ae938f80a87b18921d9 = L.geoJson(null, {
#                 onEachFeature: geo_json_a646078a72f07ae938f80a87b18921d9_onEachFeature,
#
#         });
#
#         function geo_json_a646078a72f07ae938f80a87b18921d9_add (data) {
#             geo_json_a646078a72f07ae938f80a87b18921d9
#                 .addData(data)
#                 .addTo(map_ed475621105aef5e10f283f630046453);
#         }
#             geo_json_a646078a72f07ae938f80a87b18921d9_add({&quot;bbox&quot;: [124.7893154389517, 33.17261058239259, 130.96325546758288, 38.54261253850525], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0411960872414, 35.10866377584849], [129.0263891249103, 35.09567543786908], [129.027468686406, 35.1155083560405], [129.0411960872414, 35.10866377584849]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.00445134557444, 35.078439676204596], [128.9997518119125, 35.123258941810164], [129.0121583473841, 35.13745819983691], [129.02562945082866, 35.13569484293786], [129.027468686406, 35.1155083560405], [129.0263891249103, 35.09567543786908], [129.00445134557444, 35.078439676204596]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26140&quot;, &quot;SIG_ENG_NM&quot;: &quot;Seo-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc11c\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.06453158641534, 35.141413884274215], [129.06545956779965, 35.13562671889399], [129.0411960872414, 35.10866377584849], [129.027468686406, 35.1155083560405], [129.02562945082866, 35.13569484293786], [129.06453158641534, 35.141413884274215]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26170&quot;, &quot;SIG_ENG_NM&quot;: &quot;Dong-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ub3d9\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0441284826078, 35.19946126955921], [129.04825560885078, 35.194547289853595], [129.0619699617844, 35.17929917076201], [129.06260505610896, 35.17735200319737], [129.06277510936656, 35.17729882756537], [129.0636150421614, 35.17720648095883], [129.06517650238175, 35.1770457771076], [129.06517559053268, 35.17703084217908], [129.06718207036297, 35.17638249974108], [129.06723395355255, 35.17657545112467], [129.0674237899668, 35.17652924369737], [129.0780938050298, 35.164372666167935], [129.07854283428412, 35.16316459360052], [129.08283185447527, 35.158173763598015], [129.06479001335273, 35.149327709816454], [129.0632642145734, 35.148796661739155], [129.06453158641534, 35.141413884274215], [129.02562945082866, 35.13569484293786], [129.0121583473841, 35.13745819983691], [129.01926481305176, 35.18046670766861], [129.0198882418209, 35.180696251773874], [129.02108500943768, 35.18747513680664], [129.0441284826078, 35.19946126955921]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26230&quot;, &quot;SIG_ENG_NM&quot;: &quot;Busanjin-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ubd80\uc0b0\uc9c4\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.11024005400392, 35.2101373741231], [129.11545694382227, 35.18650038207183], [129.1151769887035, 35.18354275935317], [129.04825560885078, 35.194547289853595], [129.0441284826078, 35.19946126955921

# %%
# 부산시 인구수별 분포
busan_pop_choropleth = folium.Map(location=[35.189294, 129.061272], tiles='CartoDB dark_matter', zoom_start=10)

folium.Choropleth(geo_data=busan_sgg_geo, data=busan_sgg_stat,
                  columns=['구', '인구수'], fill_color='Purples', fill_opacity=0.7, line_opacity=0.5,
                  key_on='properties.SIG_KOR_NM').add_to(busan_pop_choropleth)

busan_pop_choropleth
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1de9c2e62aa7ab14b2aed9c76359848 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1de9c2e62aa7ab14b2aed9c76359848&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1de9c2e62aa7ab14b2aed9c76359848 = L.map(
#                 &quot;map_b1de9c2e62aa7ab14b2aed9c76359848&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f7712eff05df604f75cacd06b0b3032 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b1de9c2e62aa7ab14b2aed9c76359848);
#
#
#             var choropleth_dc0fe23efbdaded2788b502f2e2406ce = L.featureGroup(
#                 {}
#             ).addTo(map_b1de9c2e62aa7ab14b2aed9c76359848);
#
#
#         function geo_json_91888e569318d52ae7ab42ab5853629f_styler(feature) {
#             switch(feature.properties.SIG_CD) {
#                 case &quot;26110&quot;: case &quot;26170&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f2f0f7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26140&quot;: case &quot;26440&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dadaeb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26230&quot;: case &quot;26350&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#54278f&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26260&quot;: case &quot;26320&quot;: case &quot;26380&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#756bb1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26290&quot;: case &quot;26410&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9e9ac8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bcbddc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_91888e569318d52ae7ab42ab5853629f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_91888e569318d52ae7ab42ab5853629f = L.geoJson(null, {
#                 onEachFeature: geo_json_91888e569318d52ae7ab42ab5853629f_onEachFeature,
#
#                 style: geo_json_91888e569318d52ae7ab42ab5853629f_styler,
#         });
#
#         function geo_json_91888e569318d52ae7ab42ab5853629f_add (data) {
#             geo_json_91888e569318d52ae7ab42ab5853629f
#                 .addData(data)
#                 .addTo(choropleth_dc0fe23efbdaded2788b502f2e2406ce);
#         }
#             geo_json_91888e569318d52ae7ab42ab5853629f_add({&quot;bbox&quot;: [124.7893154389517, 33.17261058239259, 130.96325546758288, 38.54261253850525], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0411960872414, 35.10866377584849], [129.0263891249103, 35.09567543786908], [129.027468686406, 35.1155083560405], [129.0411960872414, 35.10866377584849]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.00445134557444, 35.078439676204596], [128.9997518119125, 35.123258941810164], [129.0121583473841, 35.13745819983691], [129.02562945082866, 35.13569484293786], [129.027468686406, 35.1155083560405], [129.0263891249103, 35.09567543786908], [129.00445134557444, 35.078439676204596]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26140&quot;, &quot;SIG_ENG_NM&quot;: &quot;Seo-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc11c\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.06453158641534, 35.141413884274215], [129.06545956779965, 35.1356267

# %% [markdown]
# - 결론 : 구에 살고 있는 인구수와 스타벅스 매장수는 관계 거의 없다

# %%
# 부산시 인구수별 분포
busan_biz_choropleth = folium.Map(location=[35.189294, 129.061272], tiles='CartoDB dark_matter', zoom_start=10)

folium.Choropleth(geo_data=busan_sgg_geo, data=busan_sgg_stat,
                  columns=['구', '사업체수'], fill_color='Purples', fill_opacity=0.7, line_opacity=0.5,
                  key_on='properties.SIG_KOR_NM').add_to(busan_biz_choropleth)

busan_biz_choropleth
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_770bacf48bcd7cae28f1f6e596bc7c70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_770bacf48bcd7cae28f1f6e596bc7c70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_770bacf48bcd7cae28f1f6e596bc7c70 = L.map(
#                 &quot;map_770bacf48bcd7cae28f1f6e596bc7c70&quot;,
#                 {
#                     center: [35.189294, 129.061272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2f51e6bf1db269aa65a81d93aec759d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_770bacf48bcd7cae28f1f6e596bc7c70);
#
#
#             var choropleth_58c9985e4e78f319d283feadb3bcb4b6 = L.featureGroup(
#                 {}
#             ).addTo(map_770bacf48bcd7cae28f1f6e596bc7c70);
#
#
#         function geo_json_8c6aa1ec11bf6c88f47671158f0150e6_styler(feature) {
#             switch(feature.properties.SIG_CD) {
#                 case &quot;26140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f2f0f7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26230&quot;: case &quot;26350&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#54278f&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26260&quot;: case &quot;26290&quot;: case &quot;26410&quot;: case &quot;26470&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bcbddc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26380&quot;: case &quot;26440&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9e9ac8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;26530&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#756bb1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dadaeb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8c6aa1ec11bf6c88f47671158f0150e6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8c6aa1ec11bf6c88f47671158f0150e6 = L.geoJson(null, {
#                 onEachFeature: geo_json_8c6aa1ec11bf6c88f47671158f0150e6_onEachFeature,
#
#                 style: geo_json_8c6aa1ec11bf6c88f47671158f0150e6_styler,
#         });
#
#         function geo_json_8c6aa1ec11bf6c88f47671158f0150e6_add (data) {
#             geo_json_8c6aa1ec11bf6c88f47671158f0150e6
#                 .addData(data)
#                 .addTo(choropleth_58c9985e4e78f319d283feadb3bcb4b6);
#         }
#             geo_json_8c6aa1ec11bf6c88f47671158f0150e6_add({&quot;bbox&quot;: [124.7893154389517, 33.17261058239259, 130.96325546758288, 38.54261253850525], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.0411960872414, 35.10866377584849], [129.0263891249103, 35.09567543786908], [129.027468686406, 35.1155083560405], [129.0411960872414, 35.10866377584849]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.00445134557444, 35.078439676204596], [128.9997518119125, 35.123258941810164], [129.0121583473841, 35.13745819983691], [129.02562945082866, 35.13569484293786], [129.027468686406, 35.1155083560405], [129.0263891249103, 35.09567543786908], [129.00445134557444, 35.078439676204596]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26140&quot;, &quot;SIG_ENG_NM&quot;: &quot;Seo-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc11c\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.06453158641534, 35.141413884274215], [129.06545956779965, 35.13562671889399], [129.041196087

# %% [markdown]
# - 결론 : 각 구별 사업체수와 스타벅스 매장수는 깊은 연관이 있다
#
#          동작구는 사당역 근처 리저브 매장을 폐점했다(매출이 부진 예상)
